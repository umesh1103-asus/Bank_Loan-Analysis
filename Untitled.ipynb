# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
loan_train = pd.read_csv('train.csv')

# %%
loan_train
# Out:
#          Loan_ID Loan_Amount_Requested Length_Employed Home_Owner  \
# 0       10000001                 7,000        < 1 year       Rent
# 1       10000002                30,000         4 years   Mortgage
# 2       10000003                24,725         7 years   Mortgage
# 3       10000004                16,000        < 1 year        NaN
# 4       10000005                17,000         8 years        Own
# ...          ...                   ...             ...        ...
# 164304  10164305                20,725       10+ years       Rent
# 164305  10164306                 6,000         8 years        Own
# 164306  10164307                20,250       10+ years   Mortgage
# 164307  10164308                10,000         4 years       Rent
# 164308  10164309                 9,250       10+ years       Rent
#
#         Annual_Income           Income_Verified     Purpose_Of_Loan  \
# 0             68000.0              not verified                 car
# ...

# %%
df_train = pd.DataFrame(loan_train)
df_test = pd.DataFrame(loan_test)

# %%
df_train
# Out:
#          Loan_ID Loan_Amount_Requested Length_Employed Home_Owner  \
# 0       10000001                 7,000        < 1 year       Rent
# 1       10000002                30,000         4 years   Mortgage
# 2       10000003                24,725         7 years   Mortgage
# 3       10000004                16,000        < 1 year        NaN
# 4       10000005                17,000         8 years        Own
# ...          ...                   ...             ...        ...
# 164304  10164305                20,725       10+ years       Rent
# 164305  10164306                 6,000         8 years        Own
# 164306  10164307                20,250       10+ years   Mortgage
# 164307  10164308                10,000         4 years       Rent
# 164308  10164309                 9,250       10+ years       Rent
#
#         Annual_Income           Income_Verified     Purpose_Of_Loan  \
# 0             68000.0              not verified                 car
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164309 entries, 0 to 164308
# Data columns (total 14 columns):
# Loan_ID                    164309 non-null int64
# Loan_Amount_Requested      164309 non-null object
# Length_Employed            156938 non-null object
# Home_Owner                 138960 non-null object
# Annual_Income              139207 non-null float64
# Income_Verified            164309 non-null object
# Purpose_Of_Loan            164309 non-null object
# Debt_To_Income             164309 non-null float64
# Inquiries_Last_6Mo         164309 non-null int64
# Months_Since_Deliquency    75930 non-null float64
# Number_Open_Accounts       164309 non-null int64
# Total_Accounts             164309 non-null int64
# Gender                     164309 non-null object
# Interest_Rate              164309 non-null int64
# dtypes: float64(3), int64(5), object(6)
# memory usage: 17.6+ MB

# %%
df_train.describe()
# Out:
#             Loan_ID  Annual_Income  Debt_To_Income  Inquiries_Last_6Mo  \
# count  1.643090e+05   1.392070e+05   164309.000000       164309.000000
# mean   1.008216e+07   7.333116e+04       17.207189            0.781698
# std    4.743207e+04   6.037750e+04        7.845083            1.034747
# min    1.000000e+07   4.000000e+03        0.000000            0.000000
# 25%    1.004108e+07   4.500000e+04       11.370000            0.000000
# 50%    1.008216e+07   6.300000e+04       16.840000            0.000000
# 75%    1.012323e+07   8.869750e+04       22.780000            1.000000
# max    1.016431e+07   7.500000e+06       39.990000            8.000000
#
#        Months_Since_Deliquency  Number_Open_Accounts  Total_Accounts  \
# count             75930.000000         164309.000000   164309.000000
# mean                 34.229356             11.193818       25.067665
# std                  21.761180              4.991813       11.583067
# ...

# %%
df_train.describe(include='O')
# Out:
#        Loan_Amount_Requested Length_Employed Home_Owner    Income_Verified  \
# count                 164309          156938     138960             164309
# unique                  1290              11          5                  3
# top                   10,000       10+ years   Mortgage  VERIFIED - income
# freq                   11622           52915      70345              59421
#
#            Purpose_Of_Loan  Gender
# count               164309  164309
# unique                  14       2
# top     debt_consolidation    Male
# freq                 97101  117176

# %%
print(df_train.dtypes)
# Out:
# Loan_ID                      int64
# Loan_Amount_Requested       object
# Length_Employed             object
# Home_Owner                  object
# Annual_Income              float64
# Income_Verified             object
# Purpose_Of_Loan             object
# Debt_To_Income             float64
# Inquiries_Last_6Mo           int64
# Months_Since_Deliquency    float64
# Number_Open_Accounts         int64
# Total_Accounts               int64
# Gender                      object
# Interest_Rate                int64
# dtype: object

# %%
for column in df_train :
    g = sns.FacetGrid(df_train,col='Interest_Rate')
    g.map(plt.hist,column,bins=20)

# %%
g = sns.FacetGrid(df_train,col='Interest_Rate')
g.map(plt.hist,'Annual_Income',bins=20)

# %%
df_train.groupby('Interest_Rate')['Annual_Income'].nunique().plot(kind='bar')
plt.show()

# %%
df_train.groupby('Interest_Rate')['Loan_Amount_Requested'].nunique().plot(kind='bar')
plt.show()

# %%
df_train.isna().sum()
# Out:
# Loan_ID                        0
# Loan_Amount_Requested          0
# Length_Employed             7371
# Home_Owner                 25349
# Annual_Income              25102
# Income_Verified                0
# Purpose_Of_Loan                0
# Debt_To_Income                 0
# Inquiries_Last_6Mo             0
# Months_Since_Deliquency    88379
# Number_Open_Accounts           0
# Total_Accounts                 0
# Gender                         0
# Interest_Rate                  0
# dtype: int64

# %%
df_train = df_train.drop('Months_Since_Deliquency',axis=1)

# %%
df_train.isna().sum()
# Out:
# Loan_ID                      0
# Loan_Amount_Requested        0
# Length_Employed           7371
# Home_Owner               25349
# Annual_Income            25102
# Income_Verified              0
# Purpose_Of_Loan              0
# Debt_To_Income               0
# Inquiries_Last_6Mo           0
# Number_Open_Accounts         0
# Total_Accounts               0
# Gender                       0
# Interest_Rate                0
# dtype: int64

# %%
df_train=df_train.drop('Loan_ID',axis=1)

# %%
df_train.isna().sum()
# Out:
# Loan_Amount_Requested        0
# Length_Employed           7371
# Home_Owner               25349
# Annual_Income            25102
# Income_Verified              0
# Purpose_Of_Loan              0
# Debt_To_Income               0
# Inquiries_Last_6Mo           0
# Number_Open_Accounts         0
# Total_Accounts               0
# Gender                       0
# Interest_Rate                0
# dtype: int64

# %%
df_train.groupby('Interest_Rate')['Home_Owner'].nunique().plot(kind='bar')
plt.show()

# %%
df_train.groupby('Interest_Rate')['Total_Accounts'].nunique().plot(kind='bar')
plt.show()

# %%
df_train.groupby('Interest_Rate')['Length_Employed'].nunique().plot(kind='bar')
plt.show()

# %%
df_train.nunique()
# Out:
# Loan_Amount_Requested     1290
# Length_Employed             11
# Home_Owner                   5
# Annual_Income            12305
# Income_Verified              3
# Purpose_Of_Loan             14
# Debt_To_Income            3953
# Inquiries_Last_6Mo           9
# Number_Open_Accounts        58
# Total_Accounts             100
# Gender                       2
# Interest_Rate                3
# dtype: int64

# %%
df_train.groupby('Interest_Rate')['Annual_Income'].nunique().plot(kind='bar')
plt.show()

# %%
df_train.groupby('Length_Employed')['Interest_Rate'].nunique().plot(kind='bar')
plt.show()

# %%
df_train = df_train.drop(['Length_Employed','Home_Owner'],axis=1)

# %%
df_train
# Out:
#        Loan_Amount_Requested  Annual_Income           Income_Verified  \
# 0                      7,000        68000.0              not verified
# 1                     30,000            NaN         VERIFIED - income
# 2                     24,725        75566.4  VERIFIED - income source
# 3                     16,000        56160.0  VERIFIED - income source
# 4                     17,000        96000.0  VERIFIED - income source
# ...                      ...            ...                       ...
# 164304                20,725            NaN  VERIFIED - income source
# 164305                 6,000            NaN  VERIFIED - income source
# 164306                20,250            NaN         VERIFIED - income
# 164307                10,000            NaN              not verified
# 164308                 9,250            NaN         VERIFIED - income
#
#            Purpose_Of_Loan  Debt_To_Income  Inquiries_Last_6Mo  \
# ...

# %%
df_train.groupby('Interest_Rate')['Loan_Amount_Requested'].nunique().plot(kind='bar')
plt.show()

# %%
df_train.nunique()
# Out:
# Loan_Amount_Requested     1290
# Annual_Income            12305
# Income_Verified              3
# Purpose_Of_Loan             14
# Debt_To_Income            3953
# Inquiries_Last_6Mo           9
# Number_Open_Accounts        58
# Total_Accounts             100
# Gender                       2
# Interest_Rate                3
# dtype: int64

# %%
df_train.describe(include='O')
# Out:
#        Loan_Amount_Requested    Income_Verified     Purpose_Of_Loan  Gender
# count                 164309             164309              164309  164309
# unique                  1290                  3                  14       2
# top                   10,000  VERIFIED - income  debt_consolidation    Male
# freq                   11622              59421               97101  117176

# %%
import locale
from locale import atof
locale.setlocale(locale.LC_NUMERIC, '')
# Out:
# 'English_India.1252'

# %%
df_train['Loan_Amount_Requested'] = df_train['Loan_Amount_Requested'].apply(locale.atof)

# %%
df_train
# Out:
#         Loan_Amount_Requested  Annual_Income           Income_Verified  \
# 0                      7000.0        68000.0              not verified
# 1                     30000.0            NaN         VERIFIED - income
# 2                     24725.0        75566.4  VERIFIED - income source
# 3                     16000.0        56160.0  VERIFIED - income source
# 4                     17000.0        96000.0  VERIFIED - income source
# ...                       ...            ...                       ...
# 164304                20725.0            NaN  VERIFIED - income source
# 164305                 6000.0            NaN  VERIFIED - income source
# 164306                20250.0            NaN         VERIFIED - income
# 164307                10000.0            NaN              not verified
# 164308                 9250.0            NaN         VERIFIED - income
#
#            Purpose_Of_Loan  Debt_To_Income  Inquiries_Last_6Mo  \
# ...

# %%
from sklearn.preprocessing import Imputer 
imputer = Imputer(missing_values='NaN',strategy='mean',axis=0)
imputer = imputer.fit(df_train.iloc[:,0:2])
df_train.iloc[:,0:2] = imputer.transform(df_train.iloc[:,0:2])
# Out:
# C:\Users\umesh\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
df_train
# Out:
#         Loan_Amount_Requested  Annual_Income           Income_Verified  \
# 0                      7000.0   68000.000000              not verified
# 1                     30000.0   73331.159434         VERIFIED - income
# 2                     24725.0   75566.400000  VERIFIED - income source
# 3                     16000.0   56160.000000  VERIFIED - income source
# 4                     17000.0   96000.000000  VERIFIED - income source
# ...                       ...            ...                       ...
# 164304                20725.0   73331.159434  VERIFIED - income source
# 164305                 6000.0   73331.159434  VERIFIED - income source
# 164306                20250.0   73331.159434         VERIFIED - income
# 164307                10000.0   73331.159434              not verified
# 164308                 9250.0   73331.159434         VERIFIED - income
#
#            Purpose_Of_Loan  Debt_To_Income  Inquiries_Last_6Mo  \
# ...

# %%
df_train.describe(include='O')
# Out:
#           Income_Verified     Purpose_Of_Loan  Gender
# count              164309              164309  164309
# unique                  3                  14       2
# top     VERIFIED - income  debt_consolidation    Male
# freq                59421               97101  117176

# %%
from sklearn.preprocessing import LabelEncoder , OneHotEncoder
lencode1 = LabelEncoder()
df_train.iloc[:,8:9] = lencode1.fit_transform(df_train.iloc[:,8:9])
# Out:
# C:\Users\umesh\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df_train
# Out:
#         Loan_Amount_Requested  Annual_Income           Income_Verified  \
# 0                      7000.0   68000.000000              not verified
# 1                     30000.0   73331.159434         VERIFIED - income
# 2                     24725.0   75566.400000  VERIFIED - income source
# 3                     16000.0   56160.000000  VERIFIED - income source
# 4                     17000.0   96000.000000  VERIFIED - income source
# ...                       ...            ...                       ...
# 164304                20725.0   73331.159434  VERIFIED - income source
# 164305                 6000.0   73331.159434  VERIFIED - income source
# 164306                20250.0   73331.159434         VERIFIED - income
# 164307                10000.0   73331.159434              not verified
# 164308                 9250.0   73331.159434         VERIFIED - income
#
#            Purpose_Of_Loan  Debt_To_Income  Inquiries_Last_6Mo  \
# ...

# %%
lencode2 = LabelEncoder()
df_train.iloc[:,2:3] = lencode2.fit_transform(df_train.iloc[:,2:3])

# %%
df_train
# Out:
#         Loan_Amount_Requested  Annual_Income  Income_Verified  \
# 0                      7000.0   68000.000000                2
# 1                     30000.0   73331.159434                0
# 2                     24725.0   75566.400000                1
# 3                     16000.0   56160.000000                1
# 4                     17000.0   96000.000000                1
# ...                       ...            ...              ...
# 164304                20725.0   73331.159434                1
# 164305                 6000.0   73331.159434                1
# 164306                20250.0   73331.159434                0
# 164307                10000.0   73331.159434                2
# 164308                 9250.0   73331.159434                0
#
#            Purpose_Of_Loan  Debt_To_Income  Inquiries_Last_6Mo  \
# 0                      car           18.37                   0
# 1       debt_consolidation           14.93                   0
# ...

# %%
dt = pd.get_dummies(df_train.Income_Verified)

# %%
dt
# Out:
#         0  1  2
# 0       0  0  1
# 1       1  0  0
# 2       0  1  0
# 3       0  1  0
# 4       0  1  0
# ...    .. .. ..
# 164304  0  1  0
# 164305  0  1  0
# 164306  1  0  0
# 164307  0  0  1
# 164308  1  0  0
#
# [164309 rows x 3 columns]

# %%
df_train.insert(0,"Verified_Income1",dt[0])

# %%
df_train.insert(0,"Verified_Income2",dt[1])

# %%
df_train.insert(0,"Verified_Income3",dt[2])

# %%
df_train = df_train.drop('Verified_Income3',axis=1)

# %%
df_train
# Out:
#         Verified_Income2  Verified_Income1  Loan_Amount_Requested  \
# 0                      0                 0                 7000.0
# 1                      0                 1                30000.0
# 2                      1                 0                24725.0
# 3                      1                 0                16000.0
# 4                      1                 0                17000.0
# ...                  ...               ...                    ...
# 164304                 1                 0                20725.0
# 164305                 1                 0                 6000.0
# 164306                 0                 1                20250.0
# 164307                 0                 0                10000.0
# 164308                 0                 1                 9250.0
#
#         Annual_Income  Income_Verified     Purpose_Of_Loan  Debt_To_Income  \
# 0        68000.000000                2                 car           18.37
# ...

# %%
df_train = df_train.drop('Income_Verified',axis=1)

# %%
df_train
# Out:
#         Verified_Income2  Verified_Income1  Loan_Amount_Requested  \
# 0                      0                 0                 7000.0
# 1                      0                 1                30000.0
# 2                      1                 0                24725.0
# 3                      1                 0                16000.0
# 4                      1                 0                17000.0
# ...                  ...               ...                    ...
# 164304                 1                 0                20725.0
# 164305                 1                 0                 6000.0
# 164306                 0                 1                20250.0
# 164307                 0                 0                10000.0
# 164308                 0                 1                 9250.0
#
#         Annual_Income     Purpose_Of_Loan  Debt_To_Income  Inquiries_Last_6Mo  \
# 0        68000.000000                 car           18.37                   0
# ...

# %%
import category_encoders as ce
encode = ce.HelmertEncoder(cols=['Purpose_Of_Loan'],drop_invariant=True)
g = encode.fit_transform(df_train['Purpose_Of_Loan'])
df_train = pd.concat([df_train,g],axis=1)

# %%
df_train
# Out:
#         Verified_Income2  Verified_Income1  Loan_Amount_Requested  \
# 0                      0                 0                 7000.0
# 1                      0                 1                30000.0
# 2                      1                 0                24725.0
# 3                      1                 0                16000.0
# 4                      1                 0                17000.0
# ...                  ...               ...                    ...
# 164304                 1                 0                20725.0
# 164305                 1                 0                 6000.0
# 164306                 0                 1                20250.0
# 164307                 0                 0                10000.0
# 164308                 0                 1                 9250.0
#
#         Annual_Income     Purpose_Of_Loan  Debt_To_Income  Inquiries_Last_6Mo  \
# 0        68000.000000                 car           18.37                   0
# ...

# %%
df_train = df_train.drop('Purpose_Of_Loan',axis=1)

# %%
df_train
# Out:
#         Verified_Income2  Verified_Income1  Loan_Amount_Requested  \
# 0                      0                 0                 7000.0
# 1                      0                 1                30000.0
# 2                      1                 0                24725.0
# 3                      1                 0                16000.0
# 4                      1                 0                17000.0
# ...                  ...               ...                    ...
# 164304                 1                 0                20725.0
# 164305                 1                 0                 6000.0
# 164306                 0                 1                20250.0
# 164307                 0                 0                10000.0
# 164308                 0                 1                 9250.0
#
#         Annual_Income  Debt_To_Income  Inquiries_Last_6Mo  \
# 0        68000.000000           18.37                   0
# ...

# %%
Y = df_train['Interest_Rate']

# %%
Y
# Out:
# 0         1
# 1         3
# 2         3
# 3         3
# 4         1
#          ..
# 164304    2
# 164305    2
# 164306    1
# 164307    3
# 164308    2
# Name: Interest_Rate, Length: 164309, dtype: int64

# %%
df_train = df_train.drop('Interest_Rate',axis=1)

# %%
X = df_train.copy()

# %%
X
# Out:
#         Verified_Income2  Verified_Income1  Loan_Amount_Requested  \
# 0                      0                 0                 7000.0
# 1                      0                 1                30000.0
# 2                      1                 0                24725.0
# 3                      1                 0                16000.0
# 4                      1                 0                17000.0
# ...                  ...               ...                    ...
# 164304                 1                 0                20725.0
# 164305                 1                 0                 6000.0
# 164306                 0                 1                20250.0
# 164307                 0                 0                10000.0
# 164308                 0                 1                 9250.0
#
#         Annual_Income  Debt_To_Income  Inquiries_Last_6Mo  \
# 0        68000.000000           18.37                   0
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.1)

# %%
X_test
# Out:
#         Verified_Income2  Verified_Income1  Loan_Amount_Requested  \
# 79371                  0                 0                 6850.0
# 43628                  0                 1                 3000.0
# 53915                  1                 0                10000.0
# 4522                   0                 1                19800.0
# 120355                 0                 1                20000.0
# ...                  ...               ...                    ...
# 39932                  0                 1                12800.0
# 10646                  1                 0                 6300.0
# 85128                  0                 1                35000.0
# 89797                  0                 1                20000.0
# 160271                 0                 0                 7500.0
#
#         Annual_Income  Debt_To_Income  Inquiries_Last_6Mo  \
# 79371         23000.0           13.20                   0
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
X_train = sc_x.fit_transform(X_train)
X_test = sc_x.fit_transform(X_test)

# %%
X_test
# Out:
# array([[-0.69889201, -0.75504356, -0.90721291, ..., -0.07010923,
#         -0.02776745, -0.03218231],
#        [-0.69889201,  1.3244269 , -1.36958169, ..., -0.07010923,
#         -0.02776745, -0.03218231],
#        [ 1.43083622, -0.75504356, -0.52891118, ..., -0.07010923,
#         -0.02776745, -0.03218231],
#        ...,
#        [-0.69889201,  1.3244269 ,  2.47348352, ..., -0.07010923,
#         -0.02776745, -0.03218231],
#        [-0.69889201,  1.3244269 ,  0.6720467 , ..., -0.07010923,
#         -0.02776745, -0.03218231],
#        [-0.69889201, -0.75504356, -0.82915064, ..., -0.07010923,
#         -0.02776745, -0.03218231]])

# %%
X_train
# Out:
# array([[-0.68921601, -0.75241123,  1.16672119, ..., -0.07053378,
#         -0.02933986, -0.02678285],
#        [-0.68921601, -0.75241123, -0.52474896, ..., -0.07053378,
#         -0.02933986, -0.02678285],
#        [ 1.45092394, -0.75241123,  0.44180541, ..., -0.07053378,
#         -0.02933986, -0.02678285],
#        ...,
#        [-0.68921601,  1.32906044,  0.44180541, ..., -0.07053378,
#         -0.02933986, -0.02678285],
#        [-0.68921601, -0.75241123, -1.37048404, ..., -0.07053378,
#         -0.02933986, -0.02678285],
#        [ 1.45092394, -0.75241123,  1.89163697, ..., -0.07053378,
#         -0.02933986, -0.02678285]])

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 250)
regressor.fit(X_train,Y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=250,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
y_pred = regressor.predict(X_test)

# %%
from math import sqrt
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(Y_test,y_pred)

# %%
mse
# Out:
# 0.4734231090012781

# %%
print(np.sqrt((y_pred-Y_test)**2).mean())
# Out:
# 0.5742788631245824
